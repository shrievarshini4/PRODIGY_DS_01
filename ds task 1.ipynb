# %%
import pandas as pd

# Load the dataset
data_url = r"C:\Users\shrie\Downloads\API_SP.POP.TOTL_DS2_en_csv_v2_45183\API_SP.POP.TOTL_DS2_en_csv_v2_45183.csv"
df = pd.read_csv(data_url, skiprows=3)

# Display the first few rows of the dataset
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
df.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                2
#                  ...
# 2020                1
# 2021                1
# 2022                1
# 2023              266
# Unnamed: 68       266
# Length: 69, dtype: int64

# %%
import matplotlib.pyplot as plt



# Step 2: Filter data for six specific countries
countries_of_interest = ['China', 'India', 'United States', 'Indonesia', 'Pakistan', 'Brazil']
filtered_df = df[df['Country Name'].isin(countries_of_interest)]

# Step 3: Extract country names and total population for the selected countries
countries = filtered_df['Country Name']
total_population = filtered_df['2021']  # Assuming you want to plot the data for the year 2019

# Step 4: Create the bar graph
plt.figure(figsize=(10, 6))
plt.bar(countries, total_population, color='skyblue')
plt.title('Total Population by Country (2021)')
plt.xlabel('Country')
plt.ylabel('Total Population')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Define the list of countries of interest
countries_of_interest = ['China', 'India', 'United States', 'Indonesia', 'Pakistan', 'Brazil']

# Load hypothetical age distribution data
# Simulate age distribution data
np.random.seed(0)
age_distribution_data = {
    country: np.random.randint(1, 100, size=100) for country in countries_of_interest
}

# Specify the country you want to plot
country_to_plot = 'India'  # Change this to the desired country

# Plot histogram for the specified country
plt.figure(figsize=(10, 6))
plt.hist(age_distribution_data[country_to_plot], bins=10, alpha=0.6, label=country_to_plot)

plt.title(f'Age Distribution in {country_to_plot}')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend(title='Country')
plt.grid(True)

plt.tight_layout()
plt.show()

country_to_plot = 'China'  # Change this to the desired country

# Plot histogram for the specified country
plt.figure(figsize=(10, 6))
plt.hist(age_distribution_data[country_to_plot], bins=10, alpha=0.6, label=country_to_plot)

plt.title(f'Age Distribution in {country_to_plot}')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend(title='Country')
plt.grid(True)

plt.tight_layout()
plt.show()

country_to_plot = 'United States'  # Change this to the desired country

# Plot histogram for the specified country
plt.figure(figsize=(10, 6))
plt.hist(age_distribution_data[country_to_plot], bins=10, alpha=0.6, label=country_to_plot)

plt.title(f'Age Distribution in {country_to_plot}')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend(title='Country')
plt.grid(True)

plt.tight_layout()
plt.show()

country_to_plot = 'Indonesia'  # Change this to the desired country

# Plot histogram for the specified country
plt.figure(figsize=(10, 6))
plt.hist(age_distribution_data[country_to_plot], bins=10, alpha=0.6, label=country_to_plot)

plt.title(f'Age Distribution in {country_to_plot}')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend(title='Country')
plt.grid(True)

plt.tight_layout()
plt.show()

country_to_plot = 'Pakistan'  # Change this to the desired country

# Plot histogram for the specified country
plt.figure(figsize=(10, 6))
plt.hist(age_distribution_data[country_to_plot], bins=10, alpha=0.6, label=country_to_plot)

plt.title(f'Age Distribution in {country_to_plot}')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend(title='Country')
plt.grid(True)

plt.tight_layout()
plt.show()

country_to_plot = 'Brazil'  # Change this to the desired country

# Plot histogram for the specified country
plt.figure(figsize=(10, 6))
plt.hist(age_distribution_data[country_to_plot], bins=10, alpha=0.6, label=country_to_plot)

plt.title(f'Age Distribution in {country_to_plot}')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend(title='Country')
plt.grid(True)

plt.tight_layout()
plt.show()
